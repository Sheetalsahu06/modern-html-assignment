# %% [markdown]
# **1. List out the features of HTML5.**
# - Features of HTML5:
#   - New elements, attributes, and behaviors; support for multimedia; better error handling.
#   - New tags like `<article>, <aside>, <figure>.`
#   - Enhanced forms with new input types.
#   - Built-in audio and video support with `<audio>` and `<video>.`
#   - Local storage for offline use.
#   - Graphics and animations with `<canvas>` and `<svg>.`
#
# **2. What are HTML Entities? List out 5 commonly used HTML entities.**
# - HTML Entities:
#   - Special codes to display reserved characters.
#   - Help display symbols that have special meanings in HTML.
#   - Ensure characters are rendered correctly.
#   - Prevent HTML code from breaking.
#   - Used to display invisible characters.
#
# -  Purpose and Usage of HTML Entities:
#   - To display reserved characters, invisible characters, and non-keyboard characters.
#   - To show symbols like &, <, >.
#   - To avoid conflicts with HTML syntax.
#   - Enhance text presentation.
#   - Improve readability and user experience.
#
# - Commonly Used HTML Entities:
#
#   - `&amp;` for &
#   - `&gt;`for >
#   - `&quot;` for "
#   - `&lt;`for <
#   - `&apos;` for '
#
#
#  **3. Define accessibility in the context of web development. Discuss why it's essential to create accessible websites and how it benefits different user groups.**
#  - **What is Accessibility?:**
#    - Making web content usable for everyone.
#    - Includes people with disabilities.
#    - Ensures equal access to information.
#    - Enhances user experience.
#    - Part of web development best practices.
#
#
#  - **Why to Use Accessibility?:**
#    - Legal compliance (e.g., ADA, WCAG).
#    - Inclusivity and social responsibility.
#    - Expands audience reach.
#    - Improves SEO.
#    - Benefits all users, not just those with disabilities.
#
#  - **Benefits for Different User Groups:**
#    - **Visually Impaired Users:** Screen readers and alternative text enhance navigation.
#    - **Hearing Impaired Users:** Captions and transcripts make audio content accessible.
#    - **Motor Impaired Users:** Keyboard and voice controls improve usability.
#    - **Cognitively Impaired Users:** Simple layouts and clear instructions aid comprehension.
#
#
#  **4. List any 3 ways which help us in improving the accessibility of HTML.**
#
# - Why to Use Accessibility?:
#
#   - Legal compliance (e.g., ADA, WCAG).
#   - Inclusivity and social responsibility.
#   - Expands audience reach.
#   - Improves SEO.
#   - Benefits all users, not just those with disabilities.
#
#
# - Best Practices to follow for Accessibility:
#
#   - Use semantic HTML tags.
#   - Provide alt text for images.
#   - Ensure keyboard navigability.
#   - Use ARIA (Accessible Rich Internet Applications) landmarks.
#   - Test with screen readers and other assistive technologies.
#
#
#  **5. Create a web page that highlights the features of HTML5. Use appropriate semantic tags to structure the content and showcase at least three key features of HTML5 with explanations.**
#  ```
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>HTML5 Features</title>
# </head>
# <body>
#     <header>
#         <h1>Key Features of HTML5</h1>
#         <p>HTML5 introduces powerful new features that enhance web development.</p>
#     </header>
#
#     <section>
#         <article>
#             <h2>1. Semantic Elements</h2>
#             <p>HTML5 provides new semantic elements such as <code>&lt;header&gt;</code>, <code>&lt;section&gt;</code>, <code>&lt;article&gt;</code>, and <code>&lt;footer&gt;</code> which improve document structure and accessibility.</p>
#         </article>
#
#         <article>
#             <h2>2. Multimedia Support</h2>
#             <p>HTML5 includes native support for audio and video through the <code>&lt;audio&gt;</code> and <code>&lt;video&gt;</code> tags, eliminating the need for third-party plugins like Flash.</p>
#         </article>
#
#         <article>
#             <h2>3. Canvas for Graphics</h2>
#             <p>The <code>&lt;canvas&gt;</code> element allows dynamic rendering of graphics and animations using JavaScript, making it a powerful tool for game development and interactive web applications.</p>
#         </article>
#     </section>
# </body>
# </html>
#
#  ```
#
#  **Output:**
#  ![{A78C78BA-3291-45AE-841C-61C47730930A}.png](data:image/png;base64,...)
#
#
#  **6. Create a simple web page which has a table. The table must have 2 columns HTML and HTML5. The table should include a minimum of three rows describing the differences between HTML and HTML5.**
#  ```
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Difference between HTML and HTML5 </title>
# </head>
# <body>
#     <h2>Difference between HTML and HTML5</h2>
#     <table border="1px" cellpadding="10px">
#         <tr>
#             <th>HTML</th>
#             <th>HTML5</th>
#         </tr>
#         <tr>
#             <td>It didn’t support audio and video without the use of flash player support.</td>
#             <td>It supports audio and video controls with the use of <audio> and <video> tags.</td>
#         </tr>
#         <tr>
#             <td>Does not allow JavaScript to run in the browser.</td>
#             <td>Allows JavaScript to run in the background. This is possible due to JS Web worker API in HTML5.</td>
#         </tr>
#         <tr>
#             <td>Vector graphics are possible in HTML with the help of various technologies such as VML, Silver-light, Flash, etc.</td>
#             <td>Vector graphics are additionally an integral part of HTML5 like SVG and Canvas.</td>
#         </tr>
#     </table>
# </body>
# </html>
#  ```
#
# **Output:**
#
# ![{A2FCD237-0E48-411A-943B-7510481C7228}.png](data:image/png;base64,...)
